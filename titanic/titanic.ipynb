# %% [markdown]
# ## Titanic Intro to Kaggle dataset
#
# ### Link
# https://www.kaggle.com/jorgemarcher/my-first-titanic-notebook
#
# ## Ideas for Improvments
# ### Classifying by age
# Age is a good indicator of survival, however, its likely that theres more of a stepwise relationship between age groups and survival than a linear one. We can test this by looking at the correlation between age groups and survival.
#
# ### Discovering families
# Siblings and children may have a higher chance of survival if one is a survivor. We can use the SibSp and ParCh columns along with age to define who parents and children are, then use indicators of whether a parent survived to predict whether a child would survive.

# %%
import pandas as pd;
import numpy as np;
from matplotlib import pyplot as plt;

df = pd.read_csv("./train.csv");

# %%
from sklearn.preprocessing import OneHotEncoder

def one_hot(df, column_name):
    dummies = pd.get_dummies(df[column_name], prefix=column_name, drop_first=True)
    df = df.drop(column_name, 1);
    df = pd.concat([df, dummies], 1);
    return df

x = df.drop(["Name", "Ticket", "Cabin", "PassengerId"], 1)
x["Age"].fillna(0, inplace=True);
x = one_hot(x, "Sex");
x = one_hot(x, "Embarked");
x.head(10)
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Sex_male  Embarked_Q  \
# 0         0       3  22.0      1      0   7.2500         1           0
# 1         1       1  38.0      1      0  71.2833         0           0
# 2         1       3  26.0      0      0   7.9250         0           0
# 3         1       1  35.0      1      0  53.1000         0           0
# 4         0       3  35.0      0      0   8.0500         1           0
# 5         0       3   0.0      0      0   8.4583         1           1
# 6         0       1  54.0      0      0  51.8625         1           0
# 7         0       3   2.0      3      1  21.0750         1           0
# 8         1       3  27.0      0      2  11.1333         0           0
# 9         1       2  14.0      1      0  30.0708         0           0
#
#    Embarked_S
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1
# 5           0
# 6           1
# 7           1
# 8           1
# 9           0

# %%
corr = x.corr();
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row0_col0,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row1_col1,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row2_col2,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row3_col3,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row4_col4,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row5_col5,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row6_col6,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row7_col7,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row8_col8{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row0_col1,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row7_col3{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row0_col2{
#             background-color:  #94b6ff;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row0_col3{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row0_col4{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row0_col5{
#             background-color:  #e2dad5;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row0_col6,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row1_col2,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row1_col5,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row2_col3,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row5_col1,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row6_col0,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row6_col4,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row7_col8,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row8_col7{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row0_col7{
#             background-color:  #aac7fd;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row0_col8,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row4_col2{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row1_col0,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row3_col2,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row7_col4{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row1_col3{
#             background-color:  #84a7fc;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row1_col4{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row1_col6,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row6_col1{
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row1_col7{
#             background-color:  #d7dce3;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row1_col8{
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row2_col0{
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row2_col1{
#             background-color:  #6180e9;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row2_col4{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row2_col5{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row2_col6,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row5_col4,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row8_col2{
#             background-color:  #b6cefa;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row2_col7{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row2_col8{
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row3_col0{
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row3_col1,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row8_col1{
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row3_col4{
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row3_col5{
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row3_col6,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row4_col7,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row7_col5{
#             background-color:  #97b8ff;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row3_col7{
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row3_col8{
#             background-color:  #bad0f8;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row4_col0{
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row4_col1,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row5_col2{
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row4_col3{
#             background-color:  #dedcdb;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row4_col5{
#             background-color:  #dbdcde;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row4_col6{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row4_col8{
#             background-color:  #b7cff9;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row5_col0{
#             background-color:  #e1dad6;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row5_col3{
#             background-color:  #9bbcff;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row5_col6{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row5_col7,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row8_col0{
#             background-color:  #8db0fe;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row5_col8{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row6_col2,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row6_col7{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row6_col3{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row6_col5{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row6_col8{
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row7_col0{
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row7_col1{
#             background-color:  #dcdddd;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row7_col2{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row7_col6{
#             background-color:  #9fbfff;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row8_col3{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row8_col4,#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row8_col5{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_d6c999a2_109e_11eb_aac7_fdeeaea752e8row8_col6{
#             background-color:  #cad8ef;
#             co

# %% [markdown]
# We see stronger correlations to survival with Sex, class, and fare. This is intuitively makes sense, as the story with the Titanic is that the Men stayed on board while women and children boarded lifeboats, while class decided who was in the higher decks and able to get a head start on the flooding. Fare correlates negatively with class, higher classes (class 3 means 3rd class) paid lower fares.

# %%
from sklearn import tree;
from sklearn.model_selection import cross_validate;

y = df["Survived"]
x = x.drop("Survived", 1)
clf = tree.DecisionTreeClassifier(max_depth=3)
# clf.fit(x, y)
cross_validate(clf, x, y, scoring=["accuracy"])
# Out:
# {'fit_time': array([0.00277472, 0.00312209, 0.00248504, 0.00199056, 0.00196862]),
#  'score_time': array([0.00161433, 0.00157976, 0.00105381, 0.00110221, 0.00176954]),
#  'test_accuracy': array([0.81564246, 0.80337079, 0.80898876, 0.78651685, 0.81460674])}

# %%
clf.fit(x, y)
dot_data = tree.plot_tree(clf, feature_names=x.columns, filled=True)
